# %%
import numpy as np
import pandas as pd

# %%
data = np.random.random((4,4))
data
# Out:
# array([[0.42377838, 0.99405884, 0.23570092, 0.64070232],
#        [0.61575108, 0.07878532, 0.64723018, 0.60912742],
#        [0.90515932, 0.84612827, 0.21750122, 0.98528744],
#        [0.66827827, 0.10894123, 0.83099816, 0.49598935]])

# %%
d = pd.DataFrame(data,columns=['Val_1','Val_2','Val_3','Val_4'])
d
# Out:
#       Val_1     Val_2     Val_3     Val_4
# 0  0.423778  0.994059  0.235701  0.640702
# 1  0.615751  0.078785  0.647230  0.609127
# 2  0.905159  0.846128  0.217501  0.985287
# 3  0.668278  0.108941  0.830998  0.495989

# %% [markdown]
# # Line

# %%
d['Val_2']
# Out:
# 0    0.994059
# 1    0.078785
# 2    0.846128
# 3    0.108941
# Name: Val_2, dtype: float64

# %%
d.Val_2
# Out:
# 0    0.994059
# 1    0.078785
# 2    0.846128
# 3    0.108941
# Name: Val_2, dtype: float64

# %%
d.Val_2.plot()
# Out:
# <AxesSubplot:>

# %%
d.Val_2.plot(color='red')
# Out:
# <AxesSubplot:>

# %%
d
# Out:
#       Val_1     Val_2     Val_3     Val_4
# 0  0.423778  0.994059  0.235701  0.640702
# 1  0.615751  0.078785  0.647230  0.609127
# 2  0.905159  0.846128  0.217501  0.985287
# 3  0.668278  0.108941  0.830998  0.495989

# %%
d.plot()
# Out:
# <AxesSubplot:>

# %%
                 d.plot(subplots= True,figsize =(18,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
d
# Out:
#       Val_1     Val_2     Val_3     Val_4
# 0  0.423778  0.994059  0.235701  0.640702
# 1  0.615751  0.078785  0.647230  0.609127
# 2  0.905159  0.846128  0.217501  0.985287
# 3  0.668278  0.108941  0.830998  0.495989

# %%
d.plot(subplots= True,layout=(2,2))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
d.Val_3
# Out:
# 0    0.235701
# 1    0.647230
# 2    0.217501
# 3    0.830998
# Name: Val_3, dtype: float64

# %%
d.Val_3.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar plot

# %%
d.Val_2
# Out:
# 0    0.994059
# 1    0.078785
# 2    0.846128
# 3    0.108941
# Name: Val_2, dtype: float64

# %%
d.Val_2.plot(kind='bar',color=['r','g','y','k'])
# Out:
# <AxesSubplot:>

# %%
d.Val_2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#combine
d.plot.bar()
# Out:
# <AxesSubplot:>

# %%
d.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
d.plot.bar(subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'Val_1'}>,
#        <AxesSubplot:title={'center':'Val_2'}>,
#        <AxesSubplot:title={'center':'Val_3'}>,
#        <AxesSubplot:title={'center':'Val_4'}>], dtype=object)

# %% [markdown]
# ## d.plot(kind='bar')
# ## d.plot.bar()

# %% [markdown]
# # Scatter plot

# %%
d.plot(kind='scatter',x='Val_1',y='Val_2')
# Out:
# <AxesSubplot:xlabel='Val_1', ylabel='Val_2'>

# %%
d.plot.scatter(x='Val_2',y='Val_3')
# Out:
# <AxesSubplot:xlabel='Val_2', ylabel='Val_3'>

# %% [markdown]
# # Pie plot

# %%
d
# Out:
#       Val_1     Val_2     Val_3     Val_4
# 0  0.423778  0.994059  0.235701  0.640702
# 1  0.615751  0.078785  0.647230  0.609127
# 2  0.905159  0.846128  0.217501  0.985287
# 3  0.668278  0.108941  0.830998  0.495989

# %%
d.Val_4.plot(kind='pie',autopct='%.2f%%',explode=[0,0,0.2,0])
# Out:
# <AxesSubplot:ylabel='Val_4'>

# %%
# total d
d.plot(kind='pie',autopct='%.2f%%',explode=[0,0,0.2,0],
       subplots= True,figsize=(18,10),layout=(2,2))
# Out:
# array([[<AxesSubplot:ylabel='Val_1'>, <AxesSubplot:ylabel='Val_2'>],
#        [<AxesSubplot:ylabel='Val_3'>, <AxesSubplot:ylabel='Val_4'>]],
#       dtype=object)

# %%
d
# Out:
#       Val_1     Val_2     Val_3     Val_4
# 0  0.423778  0.994059  0.235701  0.640702
# 1  0.615751  0.078785  0.647230  0.609127
# 2  0.905159  0.846128  0.217501  0.985287
# 3  0.668278  0.108941  0.830998  0.495989

# %%
d.T.plot(kind='pie',autopct='%.2f%%',explode=[0,0,0.2,0],
       subplots= True,figsize=(18,10),layout=(2,2))
# Out:
# array([[<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>],
#        [<AxesSubplot:ylabel='2'>, <AxesSubplot:ylabel='3'>]], dtype=object)

# %% [markdown]
# # Hist

# %%
d.Val_3.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d.Val_3.plot(kind='hist',bins=[.2,.4,.8])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d.Val_3.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Val_1'}>,
#         <AxesSubplot:title={'center':'Val_2'}>],
#        [<AxesSubplot:title={'center':'Val_3'}>,
#         <AxesSubplot:title={'center':'Val_4'}>]], dtype=object)

# %% [markdown]
# # area plot

# %%
d.plot(kind='area',alpha=.4)
# Out:
# <AxesSubplot:>

# %%
d.Val_4
# Out:
# 0    0.640702
# 1    0.609127
# 2    0.985287
# 3    0.495989
# Name: Val_4, dtype: float64

# %% [markdown]
# # box plot

# %%
d.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Kde: Kernel Density Estimation plot

# %%
d.Val_2
# Out:
# 0    0.994059
# 1    0.078785
# 2    0.846128
# 3    0.108941
# Name: Val_2, dtype: float64

# %%
d.Val_2.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
s = pd.Series([12,12,14,15,12,12,10])
s.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
d.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
a = pd.Series([100,120,130,-100,-110])
a
# Out:
# 0    100
# 1    120
# 2    130
# 3   -100
# 4   -110
# dtype: int64

# %%
a.plot(kind='bar')
# Out:
# <AxesSubplot:>
