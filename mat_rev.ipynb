# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.random(10)
y
# Out:
# array([0.15896411, 0.61600181, 0.63430564, 0.05103742, 0.21914932,
#        0.37308342, 0.48804036, 0.13354637, 0.98033567, 0.95097145])

# %%
plt.scatter(range(1,11),y,label='Population')
plt.legend()

# %%
plt.scatter(range(1,11),y,label='Population')
plt.legend(loc=0)

# %% [markdown]
# ## Box plot

# %%
data = np.random.random(100)
data
# Out:
# array([0.65083879, 0.71388382, 0.1828376 , 0.99500938, 0.67413551,
#        0.91197803, 0.39985203, 0.07299871, 0.26140625, 0.64311497,
#        0.1381825 , 0.76675887, 0.23126456, 0.64507631, 0.12984828,
#        0.30369195, 0.29831562, 0.51407897, 0.89548619, 0.73740516,
#        0.07395672, 0.81470807, 0.07329707, 0.86906998, 0.80800547,
#        0.51581493, 0.93517941, 0.30068786, 0.98732747, 0.15983394,
#        0.14304015, 0.32334569, 0.65884161, 0.1678207 , 0.76557388,
#        0.06322136, 0.33204611, 0.99525441, 0.93853382, 0.35078827,
#        0.0807903 , 0.04281714, 0.81240491, 0.86427776, 0.35433077,
#        0.90683459, 0.00784809, 0.51716997, 0.5066601 , 0.05920168,
#        0.68956658, 0.07362468, 0.01249382, 0.28066086, 0.0567359 ,
#        0.43480322, 0.42241933, 0.36617898, 0.13994282, 0.6737871 ,
#        0.08432417, 0.32995629, 0.89943094, 0.65252033, 0.66761665,
#        0.39991348, 0.2606616 , 0.84200438, 0.30511268, 0.81942793,
# ...

# %%
plt.boxplot(data,notch=True,vert=False)
plt.show()

# %%
import statistics

# %%
statistics.median(data) #50% percentile
# Out:
# 0.42861127786370984

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data)
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['data_1'])
 
# Adding title
plt.title("Customized box plot")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %%
import pandas as pd

# %%
d = pd.read_csv('PimaIndiansDiabetes.csv')
d
# Out:
#      TimesPregnant  GlucoseConcentration  BloodPrs  SkinThickness  Serum  \
# 0                6                   148        72             35      0
# 1                1                    85        66             29      0
# 2                8                   183        64              0      0
# 3                1                    89        66             23     94
# 4                0                   137        40             35    168
# ..             ...                   ...       ...            ...    ...
# 763             10                   101        76             48    180
# 764              2                   122        70             27      0
# 765              5                   121        72             23    112
# 766              1                   126        60              0      0
# 767              1                    93        70             31      0
#
#       BMI  DiabetesFunct  Age  Class
# 0    33.6          0.627   50      1
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TimesPregnant         768 non-null    int64
#  1   GlucoseConcentration  768 non-null    int64
#  2   BloodPrs              768 non-null    int64
#  3   SkinThickness         768 non-null    int64
#  4   Serum                 768 non-null    int64
#  5   BMI                   768 non-null    float64
#  6   DiabetesFunct         768 non-null    float64
#  7   Age                   768 non-null    int64
#  8   Class                 768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
cnt = d.Class.value_counts()
cnt
# Out:
# 0    500
# 1    268
# Name: Class, dtype: int64

# %%
#fetch index from series
x = cnt.index
x
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
#fetch index from data
y = cnt.values
y
# Out:
# array([500, 268], dtype=int64)

# %%
#BOX PLOT
plt.bar(x,y)
plt.xticks([0,1],['Non Diabetic','Diabetic'])
plt.show()

# %% [markdown]
# From above bar plot we can conclude, we have more numberof Non diabetic patients
# than diabetic

# %%
#show interrm of %
plt.pie(y,labels=['Non Diabetic','Diabetic'],autopct='%.f%%')
#plt.xticks([0,1],['Non Diabetic','Diabetic'])
plt.show()

# %%
d.columns
# Out:
# Index(['TimesPregnant', 'GlucoseConcentration', 'BloodPrs', 'SkinThickness',
#        'Serum', 'BMI', 'DiabetesFunct', 'Age', 'Class'],
#       dtype='object')

# %%
plt.hist(d.BloodPrs)
# Out:
# (array([ 35.,   1.,   2.,  13., 107., 261., 243.,  87.,  14.,   5.]),
#  array([  0. ,  12.2,  24.4,  36.6,  48.8,  61. ,  73.2,  85.4,  97.6,
#         109.8, 122. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(d.BloodPrs)
plt.show()

# %%
d.isna().sum()
# Out:
# TimesPregnant           0
# GlucoseConcentration    0
# BloodPrs                0
# SkinThickness           0
# Serum                   0
# BMI                     0
# DiabetesFunct           0
# Age                     0
# Class                   0
# dtype: int64

# %%
plt.plot(d.BloodPrs)
